# %% [markdown]
# # Import packages

# %%
import MetaTrader5 as mt
import pandas as pd
import ml_collections
import yaml

from datetime import datetime
import pytz
import sys

sys.path.insert(0, 'D:/Intraday_trading')
from src.support import *

import time
from IPython.display import clear_output

# %%
config_dir = 'D:/Intraday_trading/configs/config.yaml'
with open(config_dir) as file:
    config = ml_collections.ConfigDict(yaml.safe_load(file))

# %%
acc_config = config.real_acc

# %% [markdown]
# # Login account

# %%
login_metatrader(acc_config = acc_config)

# %% [markdown]
# # Real-time positions monitor

# %%
df_positions = pd.DataFrame(columns = [
    'ticket', 'time', 'time_msc', 'time_update', 'time_update_msc', 'type',
    'magic', 'identifier', 'reason', 'volume', 'price_open', 'sl', 'tp',
    'price_current', 'swap', 'profit', 'symbol', 'comment', 'external_id',
    'VN_time', 'VN_time_msc', 'VN_time_update', 'VN_time_update_msc', 'updated_at'])

# %%
for _ in range(3):
    clear_output()
    df_positions, trading_symbols = positions_rt(df_positions)
    display(df_positions)
    fig = plot_positions_rt(df_positions = df_positions, trading_symbols = trading_symbols)
    fig.show()

    time.sleep(10)
# Out:
#       ticket                time                time_msc         time_update  \
# 0  302561771 2024-06-28 06:16:35 2024-06-28 06:16:35.261 2024-06-28 06:16:35
# 1  302562186 2024-06-28 07:33:08 2024-06-28 07:33:08.691 2024-06-28 07:33:08
# 2  302683525 2024-06-28 08:38:29 2024-06-28 08:38:29.924 2024-06-28 08:38:29
# 0  302561771 2024-06-28 06:16:35 2024-06-28 06:16:35.261 2024-06-28 06:16:35
# 1  302562186 2024-06-28 07:33:08 2024-06-28 07:33:08.691 2024-06-28 07:33:08
# 2  302683525 2024-06-28 08:38:29 2024-06-28 08:38:29.924 2024-06-28 08:38:29
# 0  302561771 2024-06-28 06:16:35 2024-06-28 06:16:35.261 2024-06-28 06:16:35
# 1  302562186 2024-06-28 07:33:08 2024-06-28 07:33:08.691 2024-06-28 07:33:08
# 2  302683525 2024-06-28 08:38:29 2024-06-28 08:38:29.924 2024-06-28 08:38:29
#
#           time_update_msc type magic identifier reason  volume  price_open  \
# 0 2024-06-28 06:16:35.261    0     0  302561771      1    0.03    2327.064
# 1 2024-06-28 07:33:08.691    0     0  302562186      1    0.03    2325.098
# 2 2024-06-28 08:38:29.924    0     0  302683525      1    0.03    2331.499
# 0 2024-06-28 06:16:35.261    0     0  302561771      1    0.03    2327.064
# 1 2024-06-28 07:33:08.691    0     0  302562186      1    0.03    2325.098
# 2 2024-06-28 08:38:29.924    0     0  302683525      1    0.03    2331.499
# 0 2024-06-28 06:16:35.261    0     0  302561771      1    0.03    2327.064
# 1 2024-06-28 07:33:08.691    0     0  302562186      1    0.03    2325.098
# 2 2024-06-28 08:38:29.924    0     0  302683525      1    0.03    2331.499
#
#          sl        tp  price_current  swap  profit   symbol comment  \
# 0  2315.971  2344.050       2328.846   0.0    5.35  XAUUSDm
# 1  2315.134  2343.131       2328.846   0.0   11.25  XAUUSDm
# 2  2318.461  2342.878       2328.846   0.0   -7.96  XAUUSDm
# 0  2315.971  2344.050       2328.767   0.0    5.11  XAUUSDm
# 1  2315.134  2343.131       2328.767   0.0   11.01  XAUUSDm
# 2  2318.461  2342.878       2328.767   0.0   -8.20  XAUUSDm
# 0  2315.971  2344.050       2328.961   0.0    5.69  XAUUSDm
# 1  2315.134  2343.131       2328.961   0.0   11.59  XAUUSDm
# 2  2318.461  2342.878       2328.961   0.0   -7.62  XAUUSDm
#
#   external_id             VN_time             VN_time_msc      VN_time_update  \
# 0             2024-06-28 13:16:35 2024-06-28 13:16:35.261 2024-06-28 13:16:35
# 1             2024-06-28 14:33:08 2024-06-28 14:33:08.691 2024-06-28 14:33:08
# 2             2024-06-28 15:38:29 2024-06-28 15:38:29.924 2024-06-28 15:38:29
# 0             2024-06-28 13:16:35 2024-06-28 13:16:35.261 2024-06-28 13:16:35
# 1             2024-06-28 14:33:08 2024-06-28 14:33:08.691 2024-06-28 14:33:08
# 2             2024-06-28 15:38:29 2024-06-28 15:38:29.924 2024-06-28 15:38:29
# 0             2024-06-28 13:16:35 2024-06-28 13:16:35.261 2024-06-28 13:16:35
# 1             2024-06-28 14:33:08 2024-06-28 14:33:08.691 2024-06-28 14:33:08
# 2             2024-06-28 15:38:29 2024-06-28 15:38:29.924 2024-06-28 15:38:29
#
#        VN_time_update_msc                 updated_at
# 0 2024-06-28 13:16:35.261 2024-06-28 15:50:54.551313
# 1 2024-06-28 14:33:08.691 2024-06-28 15:50:54.551313
# 2 2024-06-28 15:38:29.924 2024-06-28 15:50:54.551313
# 0 2024-06-28 13:16:35.261 2024-06-28 15:51:05.926468
# 1 2024-06-28 14:33:08.691 2024-06-28 15:51:05.926468
# 2 2024-06-28 15:38:29.924 2024-06-28 15:51:05.926468
# 0 2024-06-28 13:16:35.261 2024-06-28 15:51:16.137985
# 1 2024-06-28 14:33:08.691 2024-06-28 15:51:16.137985
# 2 2024-06-28 15:38:29.924 2024-06-28 15:51:16.137985
# ====================================================================================================
# XAUUSDm
# ====================================================================================================
